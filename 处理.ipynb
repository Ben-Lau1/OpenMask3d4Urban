# %%
import numpy as np

# %%
A=np.load("/home/zhangshuai/workshop/open_vocabulary/openmask3d/output/2025-02-18-10-23-29-experiment/scene_example_openmask3d_features.npy")

# %%
A.shape
# Out:
# (222, 768)

# %%
B=np.load('/home/zhangshuai/workshop/open_vocabulary/openmask3d/output/2025-02-18-10-23-29-experiment/scene_example_masks.pt')

# %%
B.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 B.shape
#
# AttributeError: 'NpzFile' object has no attribute 'shape'
